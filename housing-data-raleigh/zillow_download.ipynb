# %% [markdown]
# ## Download Zillow Properties That Are For Sale
#
# Using scraped Zillow data from RapidAPI.
#
# Based on <https://colab.research.google.com/drive/1yKXmGjFgDeBuq2l2PkvyAuDiywl8DF2c?usp=sharing&utm_source=google#scrollTo=Gu9OGlGTrx4k>
#
# Note that the Zillow API limits you to 40 rows of data at a time and API uses per month for free. After that, it is $0.08 per use. The "free" plan also allows you only 10 requests per minute.

# %%
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# The search is set to look at Raleigh. You can use cities, counties, and zip codes. See the API documentation.

# %%
city = 'raleigh'
state = 'nc'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Search string: raleigh, nc

# %% [markdown]
# This is the code chunk that goes to the Rapid API webpage and gets the Zillow data. The important items are in the `querystring`. You can change these options, or add new ones. See the documentation.
#
# Remember, you can only get 40 rows at a time. This means 40 houses. So, I am searching with different min and max prices to try to pull less than 40 at a time.
#
# Finally, you need to insert your own API key.

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Houses",
               "status_type":"ForSale",
               "minPrice":"375001",
               "maxPrice":"400000"}

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': "INSERT YOUR API CODE HERE"
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.28,
#    'address': '7912 Flanagan Pl, Raleigh, NC 27612',
#    'daysOnZillow': -1,
#    'price': 389000,
#    'listingDateTime': None,
#    'longitude': -78.72406,
#    'latitude': 35.86662,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '53455833',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/8f121315a1ac62204d52c3f4bfbf2f58-p_e.jpg',
#    'livingArea': 1389,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '9208 Shallcross Way, Raleigh, NC 27617',
#    'daysOnZillow': -1,
#    'price': 384500,
#    'listingDateTime': None,
#    'longitude': -78.73121,
#    'latitude': 35.90533,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '50117060',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2dfb7fe5dc907d67f4d513a1bb260d3b-p_e.jpg',
#    'livingArea': 1443,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.46,
#    'address': '3101 Sherry Dr, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 389000,
#    'listingDateTime': None,
#    'longitude': -78.585014,
#    'latitude': 35.820602,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6377140',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ce6420acbfd65b9e21f61b1c88b0386f-p_e.jpg',
#    'livingArea': 1983,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.6,
#    'address': '1509 Yakimas Rd, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 399900,
#    'listingDateTime': None,
#    'longitude': -78.65298,
#    'latitude': 35.608692,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '215490802',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f0a2f1a719a62a043babee33f78b5042-p_e.jpg',
#    'livingArea': 2221,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.46,
#    'address': '5612 Cardinal Landing Dr, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 398500,
#    'listingDateTime': None,
#    'longitude': -78.655945,
#    'latitude': 35.62761,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '50118263',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f44e77027df06c7b9b740b0b6fff3903-p_e.jpg',
#    'livingArea': 2121,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3,
#    'address': '2812 Beehnon Way, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 389000,
#    'listingDateTime': None,
#    'longitude': -78.66926,
#    'latitude': 35.74481,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6555060',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/29679fdee8a4eb3c1bc70f1ac6d368af-p_e.jpg',
#    'livingArea': 1689,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.69,
#    'address': '6116 Jordan Woods Dr, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 387500,
#    'listingDateTime': None,
#    'longitude': -78.62402,
#    'latitude': 35.606316,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6509935',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ba28278afc4a3a693015c0b7a1c4b34f-p_e.jpg',
#    'livingArea': 1900,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9583.2,
#    'address': '4401 Major Loring Way, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 399900,
#    'listingDateTime': None,
#    'longitude': -78.56102,
#    'latitude': 35.836075,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6551574',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/270505984cdc0a432075ad636ec9ac00-p_e.jpg',
#    'livingArea': 1954,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6098.4,
#    'address': '5625 Apalachicula Dr, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 385000,
#    'listingDateTime': None,
#    'longitude': -78.54643,
#    'latitude': 35.888264,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60538288',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=35.88826370239258,-78.54643249511719&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=FaV4i9tf50AnHnOfBWklDgJOd-k=',
#    'livingArea': 1951,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': None},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.73,
#    'address': '1221 Jogging Ct, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 400000,
#    'listingDateTime': None,
#    'longitude': -78.624,
#    'latitude': 35.613403,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '65331919',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/54198abea8fc131edc41724f8689bf17-p_e.jpg',
#    'livingArea': 2189,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.72,
#    'address': '3400 Sheryl Dr, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 385000,
#    'listingDateTime': None,
#    'longitude': -78.57968,
#    'latitude': 35.824543,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6421523',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3bc5e2e3e16b3fab5d28724a43ad2955-p_e.jpg',
#    'livingArea': 1579,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3920.4,
#    'address': '1812 Crag Burn Ln, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 399000,
#    'listingDateTime': None,
#    'longitude': -78.54289,
#    'latitude': 35.808014,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6557134',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c50843384aaf2c12f038934c748ece0d-p_e.jpg',
#    'livingArea': 1620,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8712,
#    'address': '1112 Oakwood Ave, Raleigh, NC 27601',
#    'daysOnZillow': -1,
#    'price': 399900,
#    'listingDateTime': None,
#    'longitude': -78.62387,
#    'latitude': 35.78424,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6427013',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ac8aab191c45ebd73234fde9bc78f477-p_e.jpg',
#    'livingArea': 1553,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 5,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.54,
#    'address': '1308 Woodline Dr, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 392000,
#    'listingDateTime': None,
#    'longitude': -78.65608,
#    'latitude': 35.630116,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60535636',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/db377b5fc533da4cacb416e5d1966383-p_e.jpg',
#    'livingArea': 1582,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10454.4,
#    'address': '3709 Notchmill Dr, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 385000,
#    'listingDateTime': None,
#    'longitude': -78.51548,
#    'latitude': 35.883396,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '62024589',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/555ff4268c454254aa601f99e93c2be0-p_e.jpg',
#    'livingArea': 1520,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '5401 Cahaba Way, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 385000,
#    'listingDateTime': None,
#    'longitude': -78.55151,
#    'latitude': 35.888973,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60538249',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5a38f0584021c6390a1c9791866a3943-p_e.jpg',
#    'livingArea': 2107,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1,
#    'address': '6000 Buffaloe Rd, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 385000,
#    'listingDateTime': None,
#    'longitude': -78.541,
#    'latitude': 35.84168,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6401551',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9991e1c975041c8469092ac995768226-p_e.jpg',
#    'livingArea': 1986,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.69,
#    'address': '2024 Queen Charlotte Pl, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 389900,
#    'listingDateTime': None,
#    'longitude': -78.45879,
#    'latitude': 35.725143,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6495793',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5836af6bf7863a55db9fbbd235a04900-p_e.jpg',
#    'livingArea': 1860,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.48,
#    'address': '1409 Woodline Dr, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 394000,
#    'listingDateTime': None,
#    'longitude': -78.65888,
#    'latitude': 35.628727,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60535622',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/c46206fa72c08f29aa06b17e6b92428e-p_e.jpg',
#    'livingArea': 1598,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6098.4,
#    'address': '1006 Carlton Ave, Raleigh, NC 27606',
#    'daysOnZillow': -1,
#    'price': 399000,
#    'listingDateTime': None,
#    'longitude': -78.68858,
#    'latitude': 35.784138,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '119341856',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/93a7d00f023aef836a62620e0e00a8c8-p_e.jpg',
#    'livingArea': 1200,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.13,
#    'address': '4912 Elizabeth Dr, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 400000,
#    'listingDateTime': None,
#    'longitude': -78.53259,
#    'latitude': 35.847,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6407247',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/95e45fde114035d63752e7433d8a5bee-p_e.jpg',
#    'livingArea': 2344,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '7213 Summerland Dr, Raleigh, NC 27612',
#    'daysOnZillow': -1,
#    'price': 392000,
#    'listingDateTime': None,
#    'longitude': -78.65694,
#    'latitude': 35.87336,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6468969',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/b72ef6e2d6e8debeec2a5836eeb9bdc2-p_e.jpg',
#    'livingArea': 1769,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.38,
#    'address': '3213 Broyhill Cir, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 398000,
#    'listingDateTime': None,
#    'longitude': -78.600105,
#    'latitude': 35.83373,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6380435',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5df865301d2ec745a495fd7b97d4bfc2-p_e.jpg',
#    'livingArea': 1831,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.26,
#    'address': '4124 Green Rd, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 400000,
#    'listingDateTime': None,
#    'longitude': -78.59049,
#    'latitude': 35.83995,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6439315',
#    'listingSubType': {'is_FSBA': True, 'is_openHouse': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/212c51d1bdbcc6c3642b6e5ce5a48d52-p_e.jpg',
#    'livingArea': 1415,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': 'Newton Plan, Dayton Woods',
#    'daysOnZillow': -1,
#    'price': 396990,
#    'listingDateTime': None,
#    'longitude': -78.69208,
#    'latitude': 35.61554,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2067586597',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a1d6a2b89aeda20272d76fa094377385-p_e.jpg',
#    'livingArea': 1564,
#    'bathrooms': 2,
#    'lotAreaUnit': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3920.4,
#    'address': '5037 Village Lawn Dr, Raleigh, NC 27613',
#    'daysOnZillow': -1,
#    'price': 399000,
#    'listingDateTime': None,
#    'longitude': -78.74346,
#    'latitude': 35.9228,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6559925',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/bd620d0ceee0e4d5efc6639c3131e4d3-p_e.jpg',
#    'livingArea': 1758,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9583.2,
#    'address': '108 Penncross Dr, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 399900,
#    'listingDateTime': None,
#    'longitude': -78.541794,
#    'latitude': 35.780025,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '132281371',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/f0752cb72f3045dd0841dd2b7aa59511-p_e.jpg',
#    'livingArea': 1438,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 3.85,
#    'address': '10401 20th Rd, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 389900,
#    'listingDateTime': None,
#    'longitude': -78.63279,
#    'latitude': 35.641823,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60535607',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/46c41f7fd7d58145892a71d94b6ed2ca-p_e.jpg',
#    'livingArea': 1550,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': 'Quinn Plan, Dayton Woods',
#    'daysOnZillow': -1,
#    'price': 378990,
#    'listingDateTime': None,
#    'longitude': -78.69208,
#    'latitude': 35.61554,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2067586596',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/168e23d69867a47125c69d2ddab470ee-p_e.jpg',
#    'livingArea': 1270,
#    'bathrooms': 2,
#    'lotAreaUnit': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 2,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': None,
#    'address': 'Dunlin Plan, 540 West',
#    'daysOnZillow': -1,
#    'price': 399990,
#    'listingDateTime': None,
#    'longitude': -78.52478,
#    'latitude': 35.808277,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '2077439454',
#    'listingSubType': {'is_newHome': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/2d60398bc9368ed44082484ff5ca53e3-p_e.jpg',
#    'livingArea': 1510,
#    'bathrooms': 2,
#    'lotAreaUnit': None,
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True}],
#  'resultsPerPage': 40,
#  'totalResultCount': 30,
#  'totalPages': 1}

# %% [markdown]
# The data gets downloaded into something called a JSON file. This is a particular type of data structure and is very common. We can convert it to a DataFrame.
#
# Note the number of rows. If your search returns 40 rows, you're probably hitting the download limit and not downloading everything that you could.

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 30
# Num of cols: 24
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY          0.28
# 1     None  SINGLE_FAMILY       6969.60
# 2     None  SINGLE_FAMILY          0.46
# 3     None  SINGLE_FAMILY          0.60
# 4     None  SINGLE_FAMILY          0.46
#
#                                        address  daysOnZillow   price  \
# 0          7912 Flanagan Pl, Raleigh, NC 27612            -1  389000
# 1       9208 Shallcross Way, Raleigh, NC 27617            -1  384500
# 2            3101 Sherry Dr, Raleigh, NC 27604            -1  389000
# 3           1509 Yakimas Rd, Raleigh, NC 27603            -1  399900
# 4  5612 Cardinal Landing Dr, Raleigh, NC 27603            -1  398500
#
#   listingDateTime  longitude   latitude contingentListingType listingStatus  \
# 0            None -78.724060  35.866620                  None      FOR_SALE
# 1            None -78.731210  35.905330                  None      FOR_SALE
# 2            None -78.585014  35.820602                  None      FOR_SALE
# 3            None -78.652980  35.608692                  None      FOR_SALE
# 4            None -78.655945  35.627610                  None      FOR_SALE
#
#         zpid                                             imgSrc  livingArea  \
# 0   53455833  https://photos.zillowstatic.com/fp/8f121315a1a...        1389
# 1   50117060  https://photos.zillowstatic.com/fp/2dfb7fe5dc9...        1443
# 2    6377140  https://photos.zillowstatic.com/fp/ce6420acbfd...        1983
# 3  215490802  https://photos.zillowstatic.com/fp/f0a2f1a719a...        2221
# 4   50118263  https://photos.zillowstatic.com/fp/f44e77027df...        2121
#
#    bathrooms lotAreaUnit country currency  bedrooms hasImage  \
# 0          3       acres     USA      USD         3     True
# 1          3        sqft     USA      USD         3     True
# 2          3       acres     USA      USD         4     True
# 3          3       acres     USA      USD         3     True
# 4          3       acres     USA      USD         3     True
#
#   listingSubType.is_FSBA listingSubType.is_openHouse  \
# 0                   True                         NaN
# 1                   True                         NaN
# 2                   True                        True
# 3                   True                         NaN
# 4                   True                         NaN
#
#   listingSubType.is_comingSoon listingSubType.is_newHome
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN

# %% [markdown]
# This is where I am taking the downloaded data, renaming it based on my search parameters (min and max prices), and saving it as a CSV file.
#
# This is really ugly code that I should just create parameter values as local variables and then loop through a list. But, it's tough to know how many observations you'll get with each search, so I'm doing it by hand.

# %%
df_z_for_sale_375001_400000 = df_z_for_sale

# %%
df_z_for_sale_0_100000.to_csv('df_z_for_sale_0_100000.csv')
df_z_for_sale_100001_200000.to_csv('df_z_for_sale_100001_200000.csv')
df_z_for_sale_200001_300000.to_csv('df_z_for_sale_200001_300000.csv')
df_z_for_sale_300001_350000.to_csv('df_z_for_sale_300001_350000.csv')
df_z_for_sale_350001_375000.to_csv('df_z_for_sale_350001_375000.csv')
df_z_for_sale_375001_400000.to_csv('df_z_for_sale_375001_400000.csv')
