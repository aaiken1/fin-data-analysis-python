# %%
import pandas as pd
import requests
import json
import time

# show all columns
pd.set_option('display.max_columns', None)

# %%
city = 'raleigh'
state = 'nc'
search_str = city + ', ' + state
print('Search string:', search_str)
# Out:
# Search string: raleigh, nc

# %%
# get data
url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":search_str,
               "home_type":"Houses"}

headers = {
    'x-rapidapi-host': "zillow-com1.p.rapidapi.com",
    'x-rapidapi-key': "654fe64f8emshc621723b3127b40p13df6fjsn96ce7e3960d8"
    }

z_for_sale_resp = requests.request("GET", url, headers=headers, params=querystring)

# transform to json
z_for_sale_resp_json = z_for_sale_resp.json()
z_for_sale_resp_json
# Out:
# {'props': [{'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 10018.8,
#    'address': '2003 Waters Dr, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 279900,
#    'listingDateTime': None,
#    'longitude': -78.61799,
#    'latitude': 35.752907,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6409690',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/14ac6c648da411bde49d077d71f8624b-p_e.jpg',
#    'livingArea': 1556,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '4720 Dillingham Ct, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.556015,
#    'latitude': 35.806217,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6505929',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/7752fce86b02252bbdb74f50d6fd1b70-p_e.jpg',
#    'livingArea': 1576,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.44,
#    'address': '5801 Coffey St, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 295000,
#    'listingDateTime': None,
#    'longitude': -78.53489,
#    'latitude': 35.797527,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6418658',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/71dd293931efefd83fce09dadee6769b-p_e.jpg',
#    'livingArea': 1750,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 2,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6534,
#    'address': '3925 Old Coach Rd, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 315500,
#    'listingDateTime': None,
#    'longitude': -78.56637,
#    'latitude': 35.834866,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6531553',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/5f917ec9d0c4d6d73d3f7a6efaa29c18-p_e.jpg',
#    'livingArea': 1446,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9583.2,
#    'address': '3805 Summer Pl, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 269500,
#    'listingDateTime': None,
#    'longitude': -78.57398,
#    'latitude': 35.83454,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6448799',
#    'listingSubType': {'is_forAuction': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/91ec4af1ee76eff2f859a49546c94392-p_e.jpg',
#    'livingArea': 1592,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 1.59,
#    'address': '10313 Ray Rd, Raleigh, NC 27613',
#    'daysOnZillow': -1,
#    'price': 300000,
#    'listingDateTime': None,
#    'longitude': -78.71925,
#    'latitude': 35.92048,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6459628',
#    'listingSubType': {'is_foreclosure': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/9d680fe6d31654446c1ad506ae89ded0-p_e.jpg',
#    'livingArea': 3754,
#    'bathrooms': 4,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7405.2,
#    'address': '4309 Grandover Dr, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 325000,
#    'listingDateTime': None,
#    'longitude': -78.563065,
#    'latitude': 35.72602,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '65342445',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4d2e5f27bb6a17ef19de37ca312c0647-p_e.jpg',
#    'livingArea': 1631,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4791.6,
#    'address': '1632 Moineau Ln, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.56926,
#    'latitude': 35.753036,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '133216057',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/89066b023b6a16b8b43216164fc51306-p_e.jpg',
#    'livingArea': 1620,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4356,
#    'address': '3875 Pin Oak Rd, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 325000,
#    'listingDateTime': None,
#    'longitude': -78.57104,
#    'latitude': 35.80529,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '70486414',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/93d4309629bec04eb6adc20424f77327-p_e.jpg',
#    'livingArea': 1482,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 4791.6,
#    'address': '3615 Cyrus St, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 298900,
#    'listingDateTime': None,
#    'longitude': -78.62144,
#    'latitude': 35.73359,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '65344664',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/e65d02a741d0d36f49e254c9d27372c0-p_e.jpg',
#    'livingArea': 1535,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.3,
#    'address': '4028 Mackinac Island Ln, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 300000,
#    'listingDateTime': None,
#    'longitude': -78.5335,
#    'latitude': 35.724155,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '50111500',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/cccf938c1322d7cb4801224b1995ea41-p_e.jpg',
#    'livingArea': 1513,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 8276.4,
#    'address': '3213 Burntwood Cir, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.61668,
#    'latitude': 35.738377,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6400134',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4c01f9d3bba37760b49bf12808fe410d-p_e.jpg',
#    'livingArea': 1327,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 2178,
#    'address': '2008 Persimmon Ridge Dr, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 314900,
#    'listingDateTime': None,
#    'longitude': -78.54319,
#    'latitude': 35.813354,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '53462105',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a23d181063f631daa4660c13d979d934-p_e.jpg',
#    'livingArea': 1338,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 2,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 6969.6,
#    'address': '4223 Viewmont Dr, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 335000,
#    'listingDateTime': None,
#    'longitude': -78.57806,
#    'latitude': 35.74206,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '50118364',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fed908dbf4c3c124154c1f0bd3b34ec7-p_e.jpg',
#    'livingArea': 1753,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9147.6,
#    'address': '2921 Henslowe Dr, Raleigh, NC 27603',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.67449,
#    'latitude': 35.749283,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6485006',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/273ea41624ab2c49a33ac2b8c2a720d8-p_e.jpg',
#    'livingArea': 1652,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.44,
#    'address': '6204 Shirley St, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 260000,
#    'listingDateTime': None,
#    'longitude': -78.53369,
#    'latitude': 35.75112,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6394419',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/1681abd03611a1bb3b10e2dacf1dafaf-p_e.jpg',
#    'livingArea': 1380,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7405.2,
#    'address': '5740 Brambleton Ave, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 315000,
#    'listingDateTime': None,
#    'longitude': -78.558716,
#    'latitude': 35.725487,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '60537382',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/fadd8fd1cd09c439ef9be8d447e0e715-p_e.jpg',
#    'livingArea': 1709,
#    'bathrooms': 2,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 9583.2,
#    'address': '816 White Daisies Ct, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 335000,
#    'listingDateTime': None,
#    'longitude': -78.54482,
#    'latitude': 35.785347,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6539273',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ee6ae1d0c9ce0a524a13d594868c8556-p_e.jpg',
#    'livingArea': 1854,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '3300 Polaris Ct, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 345000,
#    'listingDateTime': None,
#    'longitude': -78.57963,
#    'latitude': 35.825573,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6465344',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ed1587190defb90f922f6b695df529d3-p_e.jpg',
#    'livingArea': 1613,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7840.8,
#    'address': '4957 Liverpool Ln, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.55805,
#    'latitude': 35.80376,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6506295',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/38b6e1585627d0efd3d571e00ddc2708-p_e.jpg',
#    'livingArea': 1545,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 7405.2,
#    'address': '734 S State St, Raleigh, NC 27601',
#    'daysOnZillow': -1,
#    'price': 300000,
#    'listingDateTime': None,
#    'longitude': -78.624886,
#    'latitude': 35.770344,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6424781',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/4438394196531435828112c0f1a87404-p_e.jpg',
#    'livingArea': 1542,
#    'bathrooms': 0,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 0,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.28,
#    'address': '4501 Fox Rd, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.56435,
#    'latitude': 35.849068,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6466002',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/a16988c7f8da5ebdbb04dc8190f8aab7-p_e.jpg',
#    'livingArea': 1764,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 4,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.26,
#    'address': '4421 Kilcullen Dr, Raleigh, NC 27604',
#    'daysOnZillow': -1,
#    'price': 295000,
#    'listingDateTime': None,
#    'longitude': -78.58937,
#    'latitude': 35.841145,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6415389',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/3f6fa6520a5e547cc771426684ce0add-p_e.jpg',
#    'livingArea': 1320,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.4,
#    'address': '7701 Greentree Ct, Raleigh, NC 27615',
#    'daysOnZillow': -1,
#    'price': 348500,
#    'listingDateTime': None,
#    'longitude': -78.65089,
#    'latitude': 35.881054,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6452635',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/aaf601dadfef081dca3544e06340a0b2-p_e.jpg',
#    'livingArea': 1550,
#    'bathrooms': 2,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 0.25,
#    'address': '5408 Brookshadow Dr, Raleigh, NC 27610',
#    'daysOnZillow': -1,
#    'price': 350000,
#    'listingDateTime': None,
#    'longitude': -78.54375,
#    'latitude': 35.784286,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6539255',
#    'listingSubType': {'is_FSBA': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/88912c8e3bb5505c920652b0f9fb00c2-p_e.jpg',
#    'livingArea': 1676,
#    'bathrooms': 3,
#    'lotAreaUnit': 'acres',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True},
#   {'dateSold': None,
#    'propertyType': 'SINGLE_FAMILY',
#    'lotAreaValue': 5227.2,
#    'address': '4637 Draper Rd, Raleigh, NC 27616',
#    'daysOnZillow': -1,
#    'price': 330000,
#    'listingDateTime': None,
#    'longitude': -78.56529,
#    'latitude': 35.88145,
#    'contingentListingType': None,
#    'listingStatus': 'FOR_SALE',
#    'zpid': '6493454',
#    'listingSubType': {'is_comingSoon': True},
#    'imgSrc': 'https://photos.zillowstatic.com/fp/ca52d358ada4f39fca353f06de2fe322-p_e.jpg',
#    'livingArea': 1464,
#    'bathrooms': 3,
#    'lotAreaUnit': 'sqft',
#    'country': 'USA',
#    'currency': 'USD',
#    'bedrooms': 3,
#    'hasImage': True}],
#  'resultsPerPage': 40,
#  'totalResultCount': 26,
#  'totalPages': 1}

# %%
# view data
df_z_for_sale = pd.json_normalize(data=z_for_sale_resp_json['props'])
print('Num of rows:', len(df_z_for_sale))
print('Num of cols:', len(df_z_for_sale.columns))
df_z_for_sale.head()
# Out:
# Num of rows: 26
# Num of cols: 24
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY      10018.80
# 1     None  SINGLE_FAMILY       7840.80
# 2     None  SINGLE_FAMILY          0.44
# 3     None  SINGLE_FAMILY       6534.00
# 4     None  SINGLE_FAMILY       9583.20
#
#                                  address  daysOnZillow   price  \
# 0      2003 Waters Dr, Raleigh, NC 27610            -1  279900
# 1  4720 Dillingham Ct, Raleigh, NC 27604            -1  350000
# 2      5801 Coffey St, Raleigh, NC 27604            -1  295000
# 3   3925 Old Coach Rd, Raleigh, NC 27616            -1  315500
# 4      3805 Summer Pl, Raleigh, NC 27604            -1  269500
#
#   listingDateTime  longitude   latitude contingentListingType listingStatus  \
# 0            None -78.617990  35.752907                  None      FOR_SALE
# 1            None -78.556015  35.806217                  None      FOR_SALE
# 2            None -78.534890  35.797527                  None      FOR_SALE
# 3            None -78.566370  35.834866                  None      FOR_SALE
# 4            None -78.573980  35.834540                  None      FOR_SALE
#
#       zpid                                             imgSrc  livingArea  \
# 0  6409690  https://photos.zillowstatic.com/fp/14ac6c648da...        1556
# 1  6505929  https://photos.zillowstatic.com/fp/7752fce86b0...        1576
# 2  6418658  https://photos.zillowstatic.com/fp/71dd293931e...        1750
# 3  6531553  https://photos.zillowstatic.com/fp/5f917ec9d0c...        1446
# 4  6448799  https://photos.zillowstatic.com/fp/91ec4af1ee7...        1592
#
#    bathrooms lotAreaUnit country currency  bedrooms  hasImage  \
# 0          2        sqft     USA      USD         4      True
# 1          3        sqft     USA      USD         3      True
# 2          2       acres     USA      USD         2      True
# 3          3        sqft     USA      USD         3      True
# 4          3        sqft     USA      USD         4      True
#
#   listingSubType.is_FSBA listingSubType.is_forAuction  \
# 0                   True                          NaN
# 1                   True                          NaN
# 2                   True                          NaN
# 3                   True                          NaN
# 4                    NaN                         True
#
#   listingSubType.is_foreclosure listingSubType.is_comingSoon
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
